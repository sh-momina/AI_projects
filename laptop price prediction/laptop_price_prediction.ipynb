# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("laptop_data.csv")
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
# converting price into dollers from indian rupees
df["Price"] = df["Price"]*0.011824222
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   843.997396
# ...

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %% [markdown]
# ### unnamed col

# %%
df.drop(columns=["Unnamed: 0"], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   843.997396
# 1        Intel HD Graphics 6000  macOS  1.34kg   566.327299
# ...

# %% [markdown]
# ### Ram and weight col

# %%
df["Ram"] = df["Ram"].str.replace("GB", " ")
df["Weight"] = df["Weight"].str.replace("kg", " ")
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8             128GB SSD
# 1        Intel Core i5 1.8GHz   8   128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8             256GB SSD
# 3        Intel Core i7 2.7GHz  16             512GB SSD
# 4        Intel Core i5 3.1GHz   8             256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37    843.997396
# 1        Intel HD Graphics 6000  macOS  1.34    566.327299
# ...

# %%
# were onjects as remove gb and kg so to chnage datatype aswell
df["Ram"] = df["Ram"].astype("int32")
df["Weight"] = df["Weight"].astype("float32")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 101.9+ KB

# %%
import seaborn as sns

# %%
sns.displot(df["Price"])

# %% [markdown]
# ### Company col

# %%
df["Company"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Company'>

# %%
  import matplotlib.pyplot as plt

# %%
sns.barplot(x=df["Company"], y=df["Price"])
plt.xticks(rotation="vertical")
plt.show()

# %% [markdown]
# ### Typename col

# %%
df["TypeName"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='TypeName'>

# %%
sns.barplot(x=df["TypeName"], y=df["Price"])
plt.xticks(rotation="vertical")
plt.show()

# %% [markdown]
# ### Inches col

# %%
  sns.scatterplot(x=df["Inches"], y=df["Price"])
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %% [markdown]
# ### Screen resolution col

# %%
# applying value counts to chech all types
df["ScreenResolution"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='ScreenResolution'>

# %%
# making separate col of touchscreen laptops
# 1 for touch screen and 0 for non touch
df["Touchscreen"] = df["ScreenResolution"].apply(lambda x : 1 if "Touchscreen" in x else 0)
df.sample(5)
# Out:
#       Company            TypeName  Inches  \
# 71       Dell           Ultrabook    13.3
# 708    Lenovo            Notebook    14.0
# 252      Asus            Notebook    15.6
# 1040   Lenovo  2 in 1 Convertible    15.6
# 143   Toshiba            Notebook    15.6
#
#                                ScreenResolution                          Cpu  \
# 71                  IPS Panel Full HD 1920x1080   Intel Core i7 8550U 1.8GHz
# 708                           Full HD 1920x1080  Intel Core i5 6300HQ 2.3GHz
# 252                                    1366x768      AMD A9-Series 9420 3GHz
# 1040  IPS Panel Full HD / Touchscreen 1920x1080   Intel Core i7 6500U 2.5GHz
# 143                                    1366x768   Intel Core i5 6200U 2.3GHz
#
#       Ram     Memory                    Gpu       OpSys  Weight       Price  \
# 71      8  256GB SSD         AMD Radeon 530  Windows 10    1.40  601.644793
# 708     8  256GB SSD  Intel HD Graphics 520  Windows 10    1.80  750.323507
# ...

# %%
    df[df["Touchscreen"] == 1].count()
# Out:
# Company             192
# TypeName            192
# Inches              192
# ScreenResolution    192
# Cpu                 192
# Ram                 192
# Memory              192
# Gpu                 192
# OpSys               192
# Weight              192
# Price               192
# Touchscreen         192
# dtype: int64

# %%
df["Touchscreen"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Touchscreen'>

# %%
sns.barplot(x=df["Touchscreen"], y=df["Price"])
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %%
# new col for cheking if there is ips panel or not
df["IPS"] = df["ScreenResolution"].apply(lambda x : 1 if "IPS Panel" in x else 0)
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS
# 0  Intel Iris Plus Graphics 640  macOS    1.37   843.997396            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   566.327299            0    0
# ...

# %%
sns.barplot(x=df["IPS"], y=df["Price"])
# Out:
# <Axes: xlabel='IPS', ylabel='Price'>

# %%
new = df["ScreenResolution"].str.split("x", n=1, expand=True)
new.head()
df["X_res"] = new[0]
df["Y_res"] = new[1]
df["X_res"] = df["X_res"].str.replace(",","").str.findall(r"(\d+\.?\d+)").apply(lambda x:x[0])

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   843.997396            0    1
# ...

# %%
df["X_res"] = df["X_res"].astype("int")
df["Y_res"] = df["Y_res"].astype("int")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  X_res             1303 non-null   int64
#  14  Y_res             1303 non-null   int64
# dtypes: float32(1), float64(2), int32(1), int64(4), object(7)
# ...

# %%
df.corr(numeric_only=True)["Price"]
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS            0.252208
# X_res          0.556529
# Y_res          0.552809
# Name: Price, dtype: float64

# %%
# calculating ppi value 
df["ppi"] = (((df["X_res"]**2) + (df["Y_res"]**2))**0.5 / df["Inches"]).astype("float")

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   843.997396            0    1
# ...

# %%
df.corr(numeric_only=True)["Price"]
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS            0.252208
# X_res          0.556529
# Y_res          0.552809
# ppi            0.473487
# Name: Price, dtype: float64

# %%
df.drop(columns=["X_res", "Y_res", "Inches"], inplace=True)

# %%
df.drop(columns=['ScreenResolution'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   843.997396            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   566.327299            0    0
# 2         Intel HD Graphics 620  No OS    1.86   362.246865            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  1598.579666            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37  1136.258167            0    1
#
#           ppi
# 0  226.983005
# 1  127.677940
# ...

# %% [markdown]
# ### Cpu col

# %%
df["Cpu"].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core i5 7200U 2.70GHz        1
# Intel Core M M7-6Y75 1.2GHz        1
# Intel Core M 6Y54 1.1GHz           1
# AMD E-Series 9000 2.2GHz           1
# Samsung Cortex A72&A53 2.0GHz      1
# Name: count, Length: 118, dtype: int64

# %%
# extracting cpu names , only some not all 118
df["Cpu Name"] = df["Cpu"].apply(lambda x: " ".join(x.split()[0:3]))
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   843.997396            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   566.327299            0    0
# 2         Intel HD Graphics 620  No OS    1.86   362.246865            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  1598.579666            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37  1136.258167            0    1
#
#           ppi       Cpu Name
# ...

# %%
def fetchCpuBrand(text):
    if text.lower() == "intel core i3" or text.lower() == "intel core i5" or text.lower() == "intel core i7":
        return text
    else:
        if text.split()[0].lower() == "intel":
            return "Other Intel Processor"
        else:
            return "AMD Processor"

df["Cpu Brand"] = df["Cpu Name"].apply(fetchCpuBrand)
df.sample(10)
# Out:
#       Company   TypeName                                 Cpu  Ram  \
# 593   Samsung   Notebook         Intel Core i7 7700HQ 2.8GHz   16
# 308    Lenovo   Notebook          Intel Core i5 7200U 2.5GHz    8
# 79         HP   Notebook          Intel Core i5 8250U 1.6GHz    8
# 605       MSI     Gaming         Intel Core i7 7700HQ 2.8GHz   16
# 236      Acer   Notebook            Intel Core i3 6006U 2GHz    4
# 1261     Asus  Ultrabook            Intel Core M 6Y30 0.9GHz    8
# 1198     Acer   Notebook  Intel Celeron Dual Core N3350 2GHz    4
# 1227     Dell   Notebook          Intel Core i5 7200U 2.5GHz    4
# 183   Toshiba   Notebook          Intel Core i5 7200U 2.5GHz    8
# 76     Lenovo   Notebook          Intel Core i5 7200U 2.5GHz    8
#
#                     Memory                      Gpu       OpSys  Weight  \
# 593   128GB SSD +  1TB HDD  Nvidia GeForce GTX 1050  Windows 10    2.50
# 308   128GB SSD +  1TB HDD     Nvidia GeForce 940MX  Windows 10    2.30
# ...

# %%
df["Cpu Brand"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Cpu Brand'>

# %%
sns.barplot(x=df["Cpu Brand"], y=df["Price"])
plt.xticks(rotation="vertical")
plt.show()

# %%
df.drop(columns=["Cpu", "Cpu Name"], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  IPS         ppi      Cpu Brand
# 0  macOS    1.37   843.997396            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   566.327299            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   362.246865            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  1598.579666            0    1  220.534624  Intel Core i7
# 4  macOS    1.37  1136.258167            0    1  226.983005  Intel Core i5

# %% [markdown]
# ### Ram col

# %%
df["Ram"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Ram'>

# %%
sns.barplot(x=df["Ram"], y=df["Price"])
plt.xticks(rotation="vertical")
plt.show()

# %% [markdown]
# ### Memory col

# %%
df["Memory"].value_counts()
# vonverting this large column to 4 different col, SSD, HDD, Hybraid, Flasg=h storage
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 1TB SSD                           14
# 512GB SSD +  1TB HDD              14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# ...

# %%
def get_flash_storage(text):
    if "flash storage" in text.lower():
        parts = text.split()
        idx = parts.index("Flash")
        return parts[idx - 1] 
    else:
        return 0

def get_hybrid(text):
    if "hybrid" in text.lower():
        parts = text.split()
        idx = parts.index("Hybrid")
        return parts[idx - 1] 
    else:
        return 0

def get_ssd(text):
    if "ssd" in text.lower():
        parts = text.split()
        idx = parts.index("SSD")
        return parts[idx - 1] 
    else:
        return 0

def get_hdd(text):
    if "hdd" in text.lower():
        parts = text.split()
        idx = parts.index("HDD")
        return parts[idx - 1] 
    else:
        return 0

df["Flash_storage"] = df["Memory"].apply(get_flash_storage)
df["Hybrid"] = df["Memory"].apply(get_hybrid)
df["SSD"] = df["Memory"].apply(get_ssd)
df["HDD"] = df["Memory"].apply(get_hdd)

# %%
df.drop(columns=["Memory"],inplace=True)

# %%
df["SSD"] = df["SSD"].astype(str).str.replace("GB", "").str.replace("TB", "")
df["SSD"] = pd.to_numeric(df["SSD"], errors="coerce")
df["SSD"] = df["SSD"].fillna(0).astype(int)

df["HDD"] = df["HDD"].astype(str).str.replace("GB", "").str.replace("TB", "")
df["HDD"] = pd.to_numeric(df["HDD"], errors="coerce")
df["HDD"] = df["HDD"].fillna(0).astype(int)

df["Flash_storage"] = df["Flash_storage"].astype(str).str.replace("GB", "").str.replace("TB", "")
df["Flash_storage"] = pd.to_numeric(df["Flash_storage"], errors="coerce")
df["Flash_storage"] = df["Flash_storage"].fillna(0).astype(int)

df["Hybrid"] = df["Hybrid"].astype(str).str.replace("GB", "").str.replace("TB", "")
df["Hybrid"] = pd.to_numeric(df["Hybrid"], errors="coerce")
df["Hybrid"] = df["Hybrid"].fillna(0).astype(int)

# %%
df.sample(20)
# Out:
#       Company            TypeName  Ram                      Gpu       OpSys  \
# 93       Dell              Gaming    8  Nvidia GeForce GTX 1060  Windows 10
# 105        HP            Notebook    6     Nvidia GeForce 940MX  Windows 10
# 328        HP           Ultrabook    8    Intel HD Graphics 620  Windows 10
# 660      Dell            Notebook    8    Intel HD Graphics 520  Windows 10
# 267    Lenovo            Notebook    4    Intel HD Graphics 620       No OS
# 1073       HP            Notebook    8    Intel HD Graphics 620  Windows 10
# 529      Dell            Notebook    8    Intel HD Graphics 620  Windows 10
# 1241     Asus           Ultrabook    8    Intel HD Graphics 520  Windows 10
# 1228   Lenovo              Gaming   16  Nvidia GeForce GTX 960M  Windows 10
# 1195       HP            Notebook   12  Nvidia GeForce GTX 1050  Windows 10
# 374      Dell  2 in 1 Convertible    8   Intel UHD Graphics 620  Windows 10
# ...

# %%
df.corr(numeric_only=True)["Price"]
# Out:
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# Touchscreen      0.191226
# IPS              0.252208
# ppi              0.473487
# Flash_storage   -0.040511
# Hybrid          -0.004769
# SSD              0.553153
# HDD             -0.234897
# Name: Price, dtype: float64

# %%
df.drop(columns=["Hybrid", "Flash_storage"], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS         ppi      Cpu Brand  SSD  HDD
# 0   843.997396            0    1  226.983005  Intel Core i5  128    0
# 1   566.327299            0    0  127.677940  Intel Core i5    0    0
# 2   362.246865            0    0  141.211998  Intel Core i5  256    0
# 3  1598.579666            0    1  220.534624  Intel Core i7  512    0
# 4  1136.258167            0    1  226.983005  Intel Core i5  256    0

# %% [markdown]
# ### Gpu col

# %%
df["Gpu"].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# Nvidia Quadro M500M          1
# AMD Radeon R7 M360           1
# Nvidia Quadro M3000M         1
# Nvidia GeForce 960M          1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
df["Gpu Brand"] = df["Gpu"].apply(lambda x : x.split()[0])

# %%
df.sample(20)
# Out:
#      Company            TypeName  Ram                      Gpu       OpSys  \
# 732       HP            Notebook    6           AMD Radeon 520  Windows 10
# 480     Dell            Notebook    8     Nvidia GeForce 940MX  Windows 10
# 560     Acer  2 in 1 Convertible    4    Intel HD Graphics 500  Windows 10
# 851     Asus              Gaming   16  Nvidia GeForce GTX 1060  Windows 10
# 674       HP  2 in 1 Convertible    4     Nvidia GeForce 940MX  Windows 10
# 748     Dell            Notebook    8    Intel HD Graphics 620  Windows 10
# 63      Asus            Notebook    8   Intel UHD Graphics 620  Windows 10
# 897       HP            Notebook    8     Nvidia GeForce 930MX  Windows 10
# 1244      HP            Notebook    4    Intel HD Graphics 520   Windows 7
# 1117   Razer           Ultrabook    8    Intel HD Graphics 520  Windows 10
# 1146      HP           Ultrabook    8    Intel HD Graphics 520   Windows 7
# ...

# %%
df["Gpu Brand"].value_counts()
# Out:
# Gpu Brand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
# remove 1 laptop having ARM, as of no such use, a minority
df[df["Gpu Brand"] == "ARM"]
# Out:
#       Company            TypeName  Ram                Gpu      OpSys  Weight  \
# 1191  Samsung  2 in 1 Convertible    4  ARM Mali T860 MP4  Chrome OS    1.15
#
#            Price  Touchscreen  IPS       ppi      Cpu Brand  SSD  HDD  \
# 1191  415.166407            1    1  234.5074  AMD Processor    0    0
#
#      Gpu Brand
# 1191       ARM

# %%
df = df[df["Gpu Brand"] != "ARM"]

# %%
df["Gpu Brand"].value_counts()
# Out:
# Gpu Brand
# Intel     722
# Nvidia    400
# AMD       180
# Name: count, dtype: int64

# %%
sns.barplot(x=df["Gpu Brand"], y=df["Price"])
plt.xticks(rotation="vertical")
plt.show()

# %%
df.drop(columns=["Gpu"], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  IPS  \
# 0   Apple  Ultrabook    8  macOS    1.37   843.997396            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   566.327299            0    0
# 2      HP   Notebook    8  No OS    1.86   362.246865            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  1598.579666            0    1
# 4   Apple  Ultrabook    8  macOS    1.37  1136.258167            0    1
#
#           ppi      Cpu Brand  SSD  HDD Gpu Brand
# 0  226.983005  Intel Core i5  128    0     Intel
# 1  127.677940  Intel Core i5    0    0     Intel
# 2  141.211998  Intel Core i5  256    0     Intel
# 3  220.534624  Intel Core i7  512    0       AMD
# 4  226.983005  Intel Core i5  256    0     Intel

# %% [markdown]
# ### OpSys col

# %%
df["OpSys"].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
sns.barplot(x=df['OpSys'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
# we can have three categories like windown mac and other
def os_category(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'


df['OS'] = df['OpSys'].apply(os_category)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  IPS  \
# 0   Apple  Ultrabook    8  macOS    1.37   843.997396            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   566.327299            0    0
# 2      HP   Notebook    8  No OS    1.86   362.246865            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  1598.579666            0    1
# 4   Apple  Ultrabook    8  macOS    1.37  1136.258167            0    1
#
#           ppi      Cpu Brand  SSD  HDD Gpu Brand                  OS
# 0  226.983005  Intel Core i5  128    0     Intel                 Mac
# 1  127.677940  Intel Core i5    0    0     Intel                 Mac
# 2  141.211998  Intel Core i5  256    0     Intel  Others/No OS/Linux
# 3  220.534624  Intel Core i7  512    0       AMD                 Mac
# 4  226.983005  Intel Core i5  256    0     Intel                 Mac

# %%
df.drop(columns=['OpSys'],inplace=True)

# %%
sns.barplot(x=df['OS'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ### Weight col

# %%
sns.scatterplot(x=df["Weight"], y=df["Price"])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
df.corr(numeric_only=True)["Price"]
# Out:
# Ram            0.742905
# Weight         0.209867
# Price          1.000000
# Touchscreen    0.192917
# IPS            0.253320
# ppi            0.475368
# SSD            0.552944
# HDD           -0.235122
# Name: Price, dtype: float64

# %%
sns.heatmap(df.corr(numeric_only=True), )
# Out:
# <Axes: >

# %% [markdown]
# ### target col -> Price

# %%
sns.distplot(df["Price"])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_9048\941010651.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Price"])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
# are target column is skeuwed so to balance it we apply log on it
sns.distplot(np.log(df["Price"]))
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_9048\2098581974.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df["Price"]))
# <Axes: xlabel='Price', ylabel='Density'>

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Weight        Price  Touchscreen  IPS         ppi  \
# 0   Apple  Ultrabook    8    1.37   843.997396            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34   566.327299            0    0  127.677940
# 2      HP   Notebook    8    1.86   362.246865            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83  1598.579666            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37  1136.258167            0    1  226.983005
#
#        Cpu Brand  SSD  HDD Gpu Brand                  OS
# 0  Intel Core i5  128    0     Intel                 Mac
# 1  Intel Core i5    0    0     Intel                 Mac
# 2  Intel Core i5  256    0     Intel  Others/No OS/Linux
# 3  Intel Core i7  512    0       AMD                 Mac
# 4  Intel Core i5  256    0     Intel                 Mac

# %% [markdown]
# ### Model Training

# %%
X = df.drop(columns=["Price"])
y = df["Price"]

# %%
X
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  IPS         ppi  \
# 0      Apple           Ultrabook    8    1.37            0    1  226.983005
# 1      Apple           Ultrabook    8    1.34            0    0  127.677940
# 2         HP            Notebook    8    1.86            0    0  141.211998
# 3      Apple           Ultrabook   16    1.83            0    1  220.534624
# 4      Apple           Ultrabook    8    1.37            0    1  226.983005
# ...      ...                 ...  ...     ...          ...  ...         ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80            1    1  157.350512
# 1299  Lenovo  2 in 1 Convertible   16    1.30            1    1  276.053530
# 1300  Lenovo            Notebook    2    1.50            0    0  111.935204
# 1301      HP            Notebook    6    2.19            0    0  100.454670
# 1302    Asus            Notebook    4    2.20            0    0  100.454670
#
# ...

# %%
y
# Out:
# 0        843.997396
# 1        566.327299
# 2        362.246865
# 3       1598.579666
# 4       1136.258167
#            ...
# 1298     401.936522
# 1299     944.361828
# 1300     144.268752
# 1301     481.315835
# 1302     232.467988
# Name: Price, Length: 1302, dtype: float64

# %%
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=2)

# %%
step1 = ColumnTransformer(transformers=[
    ("col_transformer", OneHotEncoder(sparse_output=False, drop="first"), [0,1,7,10,11])
], remainder="passthrough")

step2 = LinearRegression()

pipe = Pipeline([
    ("step1", step1),
    ("step2", step2)
])

pipe.fit(X_train, y_train)

y_prediction = pipe.predict(X_test)

print("R2 score : ",r2_score(y_test, y_prediction))
print("Mean Absolute Error : ",mean_absolute_error(y_test, y_prediction))
# Out:
# R2 score :  0.7162755034032553
# Mean Absolute Error :  149.4070218937397

# %% [markdown]
# ### Exporting the model

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1302 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1302 non-null   object
#  1   TypeName     1302 non-null   object
#  2   Ram          1302 non-null   int32
#  3   Weight       1302 non-null   float32
#  4   Price        1302 non-null   float64
#  5   Touchscreen  1302 non-null   int64
#  6   IPS          1302 non-null   int64
#  7   ppi          1302 non-null   float64
#  8   Cpu Brand    1302 non-null   object
#  9   SSD          1302 non-null   int64
#  10  HDD          1302 non-null   int64
#  11  Gpu Brand    1302 non-null   object
#  12  OS           1302 non-null   object
# dtypes: float32(1), float64(2), int32(1), int64(4), object(5)
# memory usage: 132.2+ KB

# %%
import pickle
pickle.dump(df,open("df.pkl", "wb"))
pickle.dump(pipe,open("pipe.pkl", "wb"))

# %%
df["Weight"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       1.37
# 1       1.34
# 2       1.86
# 3       1.83
# 4       1.37
#         ...
# 1298    1.80
# 1299    1.30
# 1300    1.50
# 1301    2.19
# 1302    2.20
# Name: Weight, Length: 1302, dtype: float32>

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Weight        Price  Touchscreen  IPS         ppi  \
# 0   Apple  Ultrabook    8    1.37   843.997396            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34   566.327299            0    0  127.677940
# 2      HP   Notebook    8    1.86   362.246865            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83  1598.579666            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37  1136.258167            0    1  226.983005
#
#        Cpu Brand  SSD  HDD Gpu Brand                  OS
# 0  Intel Core i5  128    0     Intel                 Mac
# 1  Intel Core i5    0    0     Intel                 Mac
# 2  Intel Core i5  256    0     Intel  Others/No OS/Linux
# 3  Intel Core i7  512    0       AMD                 Mac
# 4  Intel Core i5  256    0     Intel                 Mac

# %%
X = df.drop(columns=["Price"])
y = df["Price"]

X_encoded = pd.get_dummies(X, drop_first=True)

X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.15, random_state=2)

model = LinearRegression()
model.fit(X_train, y_train)

model_predictions = model.predict(X_test)

print("Mean Absolute Error:", mean_absolute_error(y_test, model_predictions))
print("loss : ", mean_squared_error(y_test,model_predictions))
# Out:
# Mean Absolute Error: 149.40702189374161
# loss :  42517.31830301491

# %%
company = input(f"Enter Laptop Brand from {df['Company'].unique()}: ")
type_name = input(f"Enter Laptop Type from {df['TypeName'].unique()}: ")
ram = int(input("Enter RAM size (in GB) from [2, 4, 6, 8, 12, 16, 24, 32, 64]: "))
weight = float(input("Enter Laptop Weight (in kg): "))
touchscreen = input("Does it have a touchscreen (Yes/No): ")
ips = input("Does it have an IPS display (Yes/No): ")
screen_size = float(input("Enter Screen Size (in inches): "))
resolution = input("Enter Screen Resolution ['1920x1080','1366x768','1600x900','3840x2160','3200x1800','2880x1800','2560x1600','2560x1440','2304x1440']: ")
cpu = input(f"Enter CPU Brand from {df['Cpu Brand'].unique()}: ")
hdd = int(input("Enter HDD size (in GB) from [0, 128, 256, 512, 1024, 2048]: "))
ssd = int(input("Enter SSD size (in GB) from [0, 8, 128, 256, 512, 1024, 2048]: "))
gpu = input(f"Enter GPU Brand from {df['Gpu Brand'].unique()}: ")
os = input(f"Enter Operating System from {df['OS'].unique()}: ")

touchscreen = 1 if touchscreen.lower() == "yes" else 0

ips = 1 if ips.lower() == "yes" else 0

x_res, y_res = map(int, resolution.split("x"))

ppi = np.sqrt(x_res**2 + y_res**2) / screen_size

user_input = pd.DataFrame([{
    'Company': company,
    'TypeName': type_name,
    'Ram': ram,
    'Weight': weight,
    'Touchscreen': touchscreen,
    'IPS': ips,
    'ppi': ppi,
    'Cpu Brand': cpu,
    'HDD': hdd,
    'SSD': ssd,
    'Gpu Brand': gpu,
    'OS': os
}])
# Out:
# Enter Laptop Brand from ['Apple' 'HP' 'Acer' 'Asus' 'Dell' 'Lenovo' 'Chuwi' 'MSI' 'Microsoft'
#  'Toshiba' 'Huawei' 'Xiaomi' 'Vero' 'Razer' 'Mediacom' 'Samsung' 'Google'
#  'Fujitsu' 'LG']:  apple
# Enter Laptop Type from ['Ultrabook' 'Notebook' 'Netbook' 'Gaming' '2 in 1 Convertible'
#  'Workstation']:  notebook
# Enter RAM size (in GB) from [2, 4, 6, 8, 12, 16, 24, 32, 64]:  8
# Enter Laptop Weight (in kg):  1.75
# Does it have a touchscreen (Yes/No):  no
# Does it have an IPS display (Yes/No):  yes
# Enter Screen Size (in inches):  16
# Enter Screen Resolution ['1920x1080','1366x768','1600x900','3840x2160','3200x1800','2880x1800','2560x1600','2560x1440','2304x1440']:  1920x1080
# Enter CPU Brand from ['Intel Core i5' 'Intel Core i7' 'AMD Processor' 'Intel Core i3'
#  'Other Intel Processor']:  Intel Core i5
# Enter HDD size (in GB) from [0, 128, 256, 512, 1024, 2048]:  0
# Enter SSD size (in GB) from [0, 8, 128, 256, 512, 1024, 2048]:  512
# ...

# %%
print(user_input)
# Out:
#   Company  TypeName  Ram  Weight  Touchscreen  IPS         ppi      Cpu Brand  \
# 0   apple  notebook    8    1.75            0    1  137.681698  Intel Core i5
#
#    HDD  SSD Gpu Brand       OS
# 0    0  512     intel  windows

# %%
X = df.drop(columns=["Price"])
y = df["Price"]

X_encoded = pd.get_dummies(X, drop_first=True)

X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.15, random_state=2)

model = LinearRegression()
model.fit(X_train, y_train)

user_input_encoded = pd.get_dummies(user_input, drop_first=True)

user_input_encoded = user_input_encoded.reindex(columns=X_train.columns, fill_value=0)

prediction = model.predict(user_input_encoded)
print("Predicted Price:", prediction)

model_predictions = model.predict(X_test)

print("Mean Absolute Error:", mean_absolute_error(y_test, model_predictions))
print("Loss (MSE):", mean_squared_error(y_test, model_predictions))
# Out:
# Predicted Price: [622.93927253]
# Mean Absolute Error: 149.40702189374161
# Loss (MSE): 42517.31830301491

# %%
plt.figure(figsize=(8, 6))
plt.scatter(model_predictions, y_test, color='blue', label="Actual Data")
plt.plot(model_predictions, model_predictions, color='red', linewidth=2, label="Perfect Prediction Line")

plt.xlabel("Predicted Price")
plt.ylabel("Actual Price")
plt.title("Laptop Price Prediction vs Actual Data")
plt.legend()
plt.grid(True)
plt.show()
